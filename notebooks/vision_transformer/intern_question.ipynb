# %%
import numpy as np

# %%
a = np.array([1,2,3,4])

def mods():
    a[0] += 1
    #a += 1
    return a

# %%
b = mods()
print(a)
print(b)

# %%
a = 0

def mods():
    a += 1
    return a

# %%
b = mods()
print(a)
print(b)

# %%
a+=1

# %%
a

# %%
a = [1,2,3,4]
a+=1

# %%
a = (1,2)
a+=1

# %%
a = [1,2,3,4]
a = a + 1
print(a)

# %%
a = [1,2,3,4]
a = a + [1]
print(a)
